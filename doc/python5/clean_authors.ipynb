# %%
import os
import codecs

rexa_dir = './rexa/'
field_names = [
    'author-in-focus', 'author-in-focus-score',
    'authorlist', 'alt-authorlist', 'altTitle', 
    'editor', 'email', 'institution', 'journal',
    'abstract', 'body', 'keyword', 'title', 'year'
]
authors_f = []

for root, dirs, files in os.walk('./rexa', topdown=False):
    for f in files:
        if f.endswith('.txt'):
            authors_f.append({
                'path': '{}/{}'.format(root, f),
                'cluster_name': root.split('/')[-1]
            })
print(authors_f[0])
# Out:
# {'cluster_name': 'SusanJoRussell', 'path': './rexa/russell_s/SusanJoRussell/mention#882379.txt'}

# %%
def raw2dict(raw):
    return { entry.split(':', 1)[0].strip():entry.split(':', 1)[1].strip() for entry in raw if entry.strip() != ''}

# %%
from xml.etree import ElementTree as ET

def clean_name(xml_string):
    root = ET.fromstring(xml_string)
    return ' '.join([child.text for child in root])

# %%
def fill_na(author):
    for field in field_names:
        if author.get(field, None) is None:
            author[field] = None
    return author

# %%
authors_d = []

for author_f in authors_f:
    with codecs.open(author_f['path'], 'r', 'utf-8', errors='ignore') as f:
        author_raw = raw2dict(f.readlines())
        author_raw['cluster_name'] = author_f['cluster_name']
        authors_d.append(author_raw)
print(len(authors_d))
# Out:
# 3002

# %%
# for author_d in authors_d:
#     author_d['author-in-focus'] = clean_name(author_d['author-in-focus'])
#     author_d['authorlist'] = ', '.join([clean_name(author_name) for author_name in author_d['authorlist'].split('%%')])
#     if author_d.get('alt-authorlist', None) is not None:
#         author_d['alt-authorlist'] = ', '.join(clean_name(author_name) for author_name in author_d['alt-authorlist'].split('%%'))
#     if author_d.get('keyword', None) is not None:
#         author_d['keyword'] = ', '.join([keyword.strip() for keyword in author_d['keyword'].split(',') ])
#     if author_d.get('author-in-focus-score', None) is not None:
#         author_d['author-in-focus-score'] = float(author_d['author-in-focus-score'])
# print(authors_d[0])

# %%
# Clean author data
authors_dict = {}

for index, author_d in enumerate(authors_d):
    fill_na(author_d)
    author_d['author-in-focus'] = clean_name(author_d['author-in-focus'])
    author_d['authorlist'] = tuple([clean_name(author_name) for author_name in author_d['authorlist'].split('%%')])
    if author_d.get('alt-authorlist', None) is not None:
        author_d['alt-authorlist'] = tuple(clean_name(author_name) for author_name in author_d['alt-authorlist'].split('%%'))
    if author_d.get('keyword', None) is not None:
        author_d['keyword'] = tuple([keyword.strip() for keyword in author_d['keyword'].split(',') ])
    if author_d.get('author-in-focus-score', None) is not None:
        author_d['author-in-focus-score'] = float(author_d['author-in-focus-score'])
    authors_dict[index] = author_d

# %%
print(authors_dict.pop(1))
# Out:
# {'body': None, u'authorlist': ('SJ Russell', 'KA Steger', 'SA Johnston'), u'alt-authorlist': ('SJ Russell', 'KA Steger', 'SA Johnston'), 'institution': None, u'title': u'Subcellular localization, stoichiometry, and protein levels of 26 S proteasome subunits in yeast', u'journal': u'J Biol Chemyear: 1999', 'abstract': None, u'author-in-focus': 'SJ Russell', 'cluster_name': 'SarahJRussell', 'altTitle': None, 'editor': None, 'year': None, 'keyword': None, u'author-in-focus-score': 0.6251166, 'email': None}

# %%
from itertools import groupby
      

training_data = dict([(key, tuple(group)) for key, group in groupby(authors_d, lambda item: item['cluster_name'])])

# %%
import dedupe

fields = [
    {'field' : 'author-in-focus', 'type': 'String'},
#     {'field' : 'author-in-focus-score', 'type': 'Price'},
    {'field' : 'authorlist', 'type': 'Set'},
    {'field' : 'alt-authorlist', 'type': 'Set', 'has missing' : True},
    {'field' : 'email', 'type': 'String', 'has missing' : True},
    {'field' : 'keyword', 'type': 'Set', 'has missing' : True},
#     {'field' : 'abstract', 'type': 'Text', 'has missing' : True},
#     {'field' : 'body', 'type': 'Text', 'has missing' : True},
    {'field' : 'journal', 'type': 'String', 'has missing' : True},
    {'field' : 'institution', 'type': 'String', 'has missing' : True},
]

deduper = dedupe.Dedupe(fields)

deduper.sample(authors_dict)

match_clusters = [
    'SarahJRussell',
    'DMAllen-ohu',
    'AlvinBlum',
    'SJonesKnowEng',
    'MAJordan',
    'DKoller',
    'LHLee-elec',
    'JGMcGuire',
    'AlanMoore',
    'RajeevMotwani',
    'SebastianThrun',
    'StephenJYoung'
]

distinct_clusters = [
    ('SAYoung', 'SCKYoung'),
    ('SAYoung', 'SCKYoung'),
    ('StephenRussell', 'StephenRussellBIO'),
    ('RajeevMotwani', 'RaviMotwani'),
    ('AndrewJMoore', 'AndrewMMoore'),
    ('JBMcGuire', 'JGMcGuire'),
    ('LALee1', 'LALee2'),
    ('DKoller', 'DanielKoller'),
    ('MarilynJordan', 'MauriceJordan'),
    ('SCJones1', 'SCJones2'),
    ('AlvinBlum', 'AvrimBlum'),
    ('DAllen-jr', 'DAllen-ucla'),
]

deduper.markPairs({
    'match': [
        (training_data.get(cluster_name)[-1], training_data.get(cluster_name)[-2])
        for cluster_name in match_clusters
    ],
    'distinct': [
        (training_data.get(cluster_l)[0], training_data.get(cluster_r)[0])
        for cluster_l, cluster_r in distinct_clusters
    ]
})

print('start training...')

deduper.train()

print('finished...')

training_file = 'author_training.json'

with open(training_file, 'w') as tf:
    deduper.writeTraining(tf)
    
threshold = deduper.threshold(authors_dict, recall_weight=1)

print('clustering...')
clustered_dupes = deduper.match(authors_dict, threshold)

print('# duplicate sets', len(clustered_dupes))
# Out:
# INFO:rlr.crossvalidation:using cross validation to find optimum alpha...
# start training...
# INFO:rlr.crossvalidation:optimum alpha: 0.100000
# INFO:dedupe.blocking:Canopy: TfidfSetCanopyPredicate: (0.4, authorlist)
# INFO:dedupe.blocking:Canopy: TfidfSetCanopyPredicate: (0.2, authorlist)
# INFO:dedupe.blocking:Canopy: TfidfSetCanopyPredicate: (0.8, authorlist)
# INFO:dedupe.blocking:Canopy: TfidfSetCanopyPredicate: (0.6, authorlist)
# INFO:dedupe.blocking:Canopy: TfidfSetCanopyPredicate: (0.6, alt-authorlist)
# INFO:dedupe.blocking:Canopy: TfidfSetCanopyPredicate: (0.4, alt-authorlist)
# INFO:dedupe.blocking:Canopy: TfidfSetCanopyPredicate: (0.2, alt-authorlist)
# INFO:dedupe.blocking:Canopy: TfidfSetCanopyPredicate: (0.8, alt-authorlist)
# INFO:dedupe.blocking:Canopy: TfidfSetCanopyPredicate: (0.2, keyword)
# INFO:dedupe.blocking:Canopy: TfidfSetCanopyPredicate: (0.4, keyword)
# INFO:dedupe.blocking:Canopy: TfidfSetCanopyPredicate: (0.8, keyword)
# INFO:dedupe.blocking:Canopy: TfidfSetCanopyPredicate: (0.6, keyword)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.8, journal)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.6, journal)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.4, journal)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.2, journal)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (2, journal)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (1, journal)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (3, journal)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (4, journal)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.4, journal)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.2, journal)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.6, journal)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.8, journal)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.4, institution)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.8, institution)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.6, institution)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.2, institution)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (2, institution)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (3, institution)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (4, institution)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (1, institution)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.6, institution)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.4, institution)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.2, institution)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.8, institution)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.8, author-in-focus)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.6, author-in-focus)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.2, author-in-focus)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.4, author-in-focus)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (2, author-in-focus)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (3, author-in-focus)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (4, author-in-focus)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (1, author-in-focus)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.6, author-in-focus)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.8, author-in-focus)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.4, author-in-focus)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.2, author-in-focus)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.6, email)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.2, email)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.8, email)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.4, email)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (3, email)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (1, email)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (2, email)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (4, email)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.2, email)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.4, email)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.6, email)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.8, email)
# INFO:dedupe.blocking:Canopy: TfidfSetCanopyPredicate: (0.4, authorlist)
# INFO:dedupe.blocking:Canopy: TfidfSetCanopyPredicate: (0.2, authorlist)
# INFO:dedupe.blocking:Canopy: TfidfSetCanopyPredicate: (0.8, authorlist)
# INFO:dedupe.blocking:Canopy: TfidfSetCanopyPredicate: (0.6, authorlist)
# INFO:dedupe.blocking:Canopy: TfidfSetCanopyPredicate: (0.6, alt-authorlist)
# INFO:dedupe.blocking:Canopy: TfidfSetCanopyPredicate: (0.4, alt-authorlist)
# INFO:dedupe.blocking:Canopy: TfidfSetCanopyPredicate: (0.2, alt-authorlist)
# INFO:dedupe.blocking:Canopy: TfidfSetCanopyPredicate: (0.8, alt-authorlist)
# INFO:dedupe.blocking:Canopy: TfidfSetCanopyPredicate: (0.2, keyword)
# INFO:dedupe.blocking:Canopy: TfidfSetCanopyPredicate: (0.4, keyword)
# INFO:dedupe.blocking:Canopy: TfidfSetCanopyPredicate: (0.8, keyword)
# INFO:dedupe.blocking:Canopy: TfidfSetCanopyPredicate: (0.6, keyword)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.8, journal)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.6, journal)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.4, journal)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.2, journal)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (2, journal)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (1, journal)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (3, journal)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (4, journal)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.4, journal)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.2, journal)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.6, journal)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.8, journal)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.4, institution)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.8, institution)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.6, institution)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.2, institution)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (2, institution)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (3, institution)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (4, institution)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (1, institution)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.6, institution)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.4, institution)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.2, institution)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.8, institution)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.8, author-in-focus)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.6, author-in-focus)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.2, author-in-focus)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.4, author-in-focus)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (2, author-in-focus)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (3, author-in-focus)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (4, author-in-focus)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (1, author-in-focus)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.6, author-in-focus)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.8, author-in-focus)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.4, author-in-focus)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.2, author-in-focus)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.6, email)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.2, email)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.8, email)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.4, email)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (3, email)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (1, email)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (2, email)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (4, email)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.2, email)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.4, email)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.6, email)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.8, email)
# INFO:dedupe.training:Final predicate set:
# INFO:dedupe.training:(ExistsPredicate: (Exists, journal), TfidfNGramCanopyPredicate: (0.2, author-in-focus))
# INFO:dedupe.training:(SimplePredicate: (magnitudeOfCardinality, authorlist), SimplePredicate: (twoGramFingerprint, author-in-focus))
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.2, author-in-focus)
# finished...
# INFO:dedupe.api:Maximum expected recall and precision
# INFO:dedupe.api:recall: 0.786
# INFO:dedupe.api:precision: 0.650
# INFO:dedupe.api:With threshold: 0.355
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.2, author-in-focus)
# clustering...
# ('# duplicate sets', 138)

# %%
clustered_dupes[-1]
# Out:
# ((2559, 2560), (0.88590854, 0.88590854))

# %%
# import pandas as pd

# authors_df = pd.DataFrame.from_dict(authors_d)
# authors_df.describe()
# Out:
#                                                  abstract  \
# count                                                 746
# unique                                                726
# top     Abstract Many algorithms rely critically on be...
# freq                                                    2
#
#               alt-authorlist  \
# count                   2965
# unique                  2138
# top     Simon L Peyton Jones
# freq                      28
#
#                                                  altTitle author-in-focus  \
# count                                                 219            3002
# unique                                                214             312
# top     Experiences with an interactive museum tour-gu...       R Motwani
# freq                                                    2             161
#
#        author-in-focus-score            authorlist  \
# count                   3002                  3002
# unique                    48                  2136
# top                      1.0  Simon L Peyton Jones
# freq                    1169                    30
#
#                                                      body editor  \
# count                                                 719     93
# unique                                                708     89
# top     1 Introduction The performance of many learnin...   ed.,
# freq                                                    2      2
#
#                           email  \
# count                       275
# unique                      161
# top     russell@cs.berkeley.edu
# freq                         13
#
#                                               institution  \
# count                                                 629
# unique                                                373
# top     School of Computer Science Carnegie Mellon Uni...
# freq                                                   19
#
#                             journal  \
# count                          1227
# unique                         1163
# top     Technical report,year: 1992
# freq                              7
#
#                                                   keyword  \
# count                                                 114
# unique                                                112
# top     Keywords: Approximation, Prize Collecting Trav...
# freq                                                    2
#
#                                              title  year
# count                                         3002    65
# unique                                        2864    17
# top     Artificial Intelligence: A Modern Approach  2001
# freq                                             4     8

# %%
# authors_df
# Out:
#                                                abstract  \
# 0     "Investigations in Number, Data and Space" is ...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7     Abstract. Memory-bounded algorithms such as Ko...
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11    Abstract This paper investigates conditions un...
# 12    Abstract Automatic symbolic traffic scene anal...
# 13                                                  NaN
# 14                                                  NaN
# 15    Abstract We propose a new class of learning al...
# 16    Abstract Dynamic Bayesian networks (DBNs) are ...
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24    Abstract In this paper we provide algorithms f...
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28    Abstract A key open problem in reinforcement l...
# 29    Abstract Object identification---the task of d...
# ...                                                 ...
# 2972                                                NaN
# 2973                                                NaN
# 2974                                                NaN
# 2975                                                NaN
# 2976                                                NaN
# 2977                                                NaN
# 2978                                                NaN
# 2979                                                NaN
# 2980                                                NaN
# 2981                                                NaN
# 2982                                                NaN
# 2983                                                NaN
# 2984                                                NaN
# 2985                                                NaN
# 2986  Abstract The claim is often made that function...
# 2987                                                NaN
# 2988                                                NaN
# 2989                                                NaN
# 2990                                                NaN
# 2991                                                NaN
# 2992                                                NaN
# 2993                                                NaN
# 2994  0353236 Ruggles This international research an...
# 2995  Through the NSF Historically Black Colleges an...
# 2996                                                NaN
# 2997                                                NaN
# 2998                                                NaN
# 2999                                                NaN
# 3000                                                NaN
# 3001                                                NaN
#
#                                          alt-authorlist  \
# 0                                                   NaN
# 1                    SJ Russell, KA Steger, SA Johnston
# 2                 P J Russell, J M Doenias, S J Russell
# 3     C J Lowenstein, E W Alley, P Raval, A M Snowma...
# 4     R B Lorsbach, W J Murphy, C J Lowenstein, S H ...
# 5                                              S Russel
# 6                           A Y Ng, D Harada, S Russell
# 7                                        Stuart Russell
# 8                                             S Russell
# 9              Ronald Parr, Stuart Russell, Mike Malone
# 10                                  S Russell, P Norvig
# 11                          A Y Ng, D Harada, S Russell
# 12    T Huang, D Koller, J Malik, G Ogasawara, B Rao...
# 13                               M Fehling, S J Russell
# 14                         B Milch, B Marthi, S Russell
# 15    Nando de Freitas, Pedro A d F R Hjen-Srensen, ...
# 16                     Geoffrey Zweig, Stuart J Russell
# 17                 Shlomo Zilberstein, Stuart J Russell
# 18              E P Xing, A Y Ng, M I Jordan, S Russell
# 19                           S Zilberstein, S J Russell
# 20            S Russell, J Binder, D Koller, K Kanazawa
# 21           Andrew Y Ng, Daishi Harada, Stuart Russell
# 22                               M Braverman, S Russell
# 23    D Koller, J Weber, T Huang, J Malik, G Ogasawa...
# 24                            Eyal Amir, Stuart Russell
# 25                                    J Tash, S Russell
# 26                           S Zilberstein, S J Russell
# 27                                       Stuart Russell
# 28                           V Papavassiliou, S Russell
# 29                        Timothy Huang, Stuart Russell
# ...                                                 ...
# 2972                      Steve Jones, Gordon W Paynter
# 2973                                A Cockburn, S Jones
# 2974                         Andy Cockburn, Steve Jones
# 2975                                  R Satava, S Jones
# 2976                             S C Jones, W E Rozelle
# 2977                    Simon B Jones, Daniel Le Mtayer
# 2978    Peter Henderson, Geraint A Jones, Simon B Jones
# 2979                               S P Booth, S B Jones
# 2980                       Simon P Booth, Simon B Jones
# 2981                             Simon B Jones, M White
# 2982                      V Jones, S Jones, C Minkowitz
# 2983                       Simon B Jones, Andrew S Tyas
# 2984                                      Simon B Jones
# 2985                       Simon P Booth, Simon B Jones
# 2986                                      Simon B Jones
# 2987                           S B Jones, D Le M'etayer
# 2988                                      Simon B Jones
# 2989                                      Simon B Jones
# 2990                                      Simon B Jones
# 2991                           Simon B Jones, Daniel Le
# 2992                       Simon B Jones, Simon P Booth
# 2993                                      Simon B Jones
# 2994                                                NaN
# 2995                                                NaN
# 2996                                    Stephen E Jones
# 2997                                        Steve Jones
# 2998                       Steve Jones, Steve Meyfroidt
# 2999  S M Belmore, J M Yates, D R Bellack, S N Jones...
# 3000  Robert A Campbell, Suzanne Jones, Rachelle Cottle
# 3001  S M Bobbio, M D Kellam, B W Dudley, S Goodwin-...
#
#                                                altTitle   author-in-focus  \
# 0                                                   NaN  Susan Jo Russell
# 1                                                   NaN        SJ Russell
# 2                                                   NaN       S J Russell
# 3                                                   NaN       S W Russell
# 4                                                   NaN       S W Russell
# 5                                                   NaN          S Russel
# 6                                                   NaN         S Russell
# 7                                                   NaN    Stuart Russell
# 8                                                   NaN         S Russell
# 9                                                   NaN    Stuart Russell
# 10                    Artificial Intelligence: A Modern         S Russell
# 11                                                  NaN  Stuart J Russell
# 12                                                  NaN  Stuart J Russell
# 13                                                  NaN       S J Russell
# 14                                                  NaN         S Russell
# 15                                                  NaN  Stuart J Russell
# 16                                                  NaN  Stuart J Russell
# 17                                                  NaN       S J Russell
# 18                            Distance metric learning,         S Russell
# 19             In Imprecise and approximate Computation         S Russell
# 20                                                  NaN  Stuart J Russell
# 21    Policy invariance under reward transformations...    Stuart Russell
# 22                                                  NaN         S Russell
# 23                                                  NaN         S Russell
# 24                                                  NaN    Stuart Russell
# 25    Solving H -horizon, stationary Markov decision...         S Russell
# 26                                                  NaN       S J Russell
# 27                                                  NaN    Stuart Russell
# 28                                                  NaN  Stuart J Russell
# 29                                                  NaN  Stuart J Russell
# ...                                                 ...               ...
# 2972                                                NaN       Steve Jones
# 2973                                                NaN           S Jones
# 2974                                                NaN       Steve Jones
# 2975                                                NaN           S Jones
# 2976                                                NaN         S C Jones
# 2977                                                NaN     Simon B Jones
# 2978                                                NaN     Simon B Jones
# 2979                                                NaN         S B Jones
# 2980                                                NaN     Simon B Jones
# 2981                                               In [     Simon B Jones
# 2982                                                NaN           S Jones
# 2983                     Workshops in Computer Science,     Simon B Jones
# 2984                                                NaN     Simon B Jones
# 2985                                                NaN     Simon B Jones
# 2986                                                NaN     Simon B Jones
# 2987                                                NaN     Simon B Jones
# 2988                                                NaN     Simon B Jones
# 2989                                                NaN     Simon B Jones
# 2990                                                NaN     Simon B Jones
# 2991                                                NaN     Simon B Jones
# 2992                                                NaN     Simon B Jones
# 2993  Compile-time garbage collection by sharing ana...     Simon B Jones
# 2994                                                NaN      Sharon Jones
# 2995                                                NaN      Stacey Jones
# 2996                                                NaN   Stephen E Jones
# 2997                                                NaN       Steve Jones
# 2998                                                NaN       Steve Jones
# 2999                                                NaN         S N Jones
# 3000                                                NaN     Suzanne Jones
# 3001                                                NaN         S K Jones
#
#      author-in-focus-score                                         authorlist  \
# 0               0.60451025              Susan Jo Russell, Karen Economopoulos
# 1                0.6251166                 SJ Russell, KA Steger, SA Johnston
# 2               0.60451025              P J Russell, J M Doenias, S J Russell
# 3               0.60451025  C J Lowenstein, E W Alley, P Raval, A M Snowma...
# 4               0.60451025  R B Lorsbach, W J Murphy, C J Lowenstein, S H ...
# 5                      1.0                                           S Russel
# 6                0.6251166                        A Y Ng, D Harada, S Russell
# 7                0.6251166                                     Stuart Russell
# 8                0.6251166                                          S Russell
# 9                0.6251166           Ronald Parr, Stuart Russell, Mike Malone
# 10               0.6251166                                S Russell, P Norvig
# 11              0.60451025       Andrew Y Ng, Daishi Harada, Stuart J Russell
# 12              0.60451025  Timothy Huang, Daphne Koller, Jitendra Malik, ...
# 13              0.60451025                             M Fehling, S J Russell
# 14               0.6251166                       B Milch, B Marthi, S Russell
# 15              0.60451025  Nando de Freitas, Pedro A d F R Hjen-Srensen, ...
# 16              0.60451025                   Geoffrey Zweig, Stuart J Russell
# 17              0.60451025                         S Zilberstein, S J Russell
# 18               0.6251166            E P Xing, A Y Ng, M I Jordan, S Russell
# 19               0.6251166                           S Zilberstein, S Russell
# 20              0.60451025  Stuart J Russell, John Binder, Daphne Koller, ...
# 21               0.6251166         Andrew Y Ng, Daishi Harada, Stuart Russell
# 22               0.6251166                             M Braverman, S Russell
# 23               0.6251166  D Koller, J Weber, T Huang, J Malik, G Ogasawa...
# 24               0.6251166                          Eyal Amir, Stuart Russell
# 25               0.6251166                                  J Tash, S Russell
# 26              0.60451025                         S Zilberstein, S J Russell
# 27               0.6251166                                     Stuart Russell
# 28              0.60451025         Vassilis A Papavassiliou, Stuart J Russell
# 29              0.60451025                    Timothy Huang, Stuart J Russell
# ...                    ...                                                ...
# 2972                   1.0                      Steve Jones, Gordon W Paynter
# 2973                   1.0                                A Cockburn, S Jones
# 2974                   1.0                         Andy Cockburn, Steve Jones
# 2975                   1.0                                  R Satava, S Jones
# 2976             0.9755763                             S C Jones, W E Rozelle
# 2977             0.9755763                    Simon B Jones, Daniel Le Mtayer
# 2978             0.9755763    Peter Henderson, Geraint A Jones, Simon B Jones
# 2979             0.9755763                               S P Booth, S B Jones
# 2980             0.9755763                       Simon P Booth, Simon B Jones
# 2981             0.9755763                             Simon B Jones, M White
# 2982                   1.0                      V Jones, S Jones, C Minkowitz
# 2983             0.9755763                       Simon B Jones, Andrew S Tyas
# 2984             0.9755763                                      Simon B Jones
# 2985             0.9755763                       Simon P Booth, Simon B Jones
# 2986             0.9755763                                      Simon B Jones
# 2987             0.9755763                    Simon B Jones, Daniel Le Mtayer
# 2988             0.9755763                                      Simon B Jones
# 2989             0.9755763                                      Simon B Jones
# 2990             0.9755763                                      Simon B Jones
# 2991             0.9755763                           Simon B Jones, Daniel Le
# 2992             0.9755763                       Simon B Jones, Simon P Booth
# 2993             0.9755763                                      Simon B Jones
# 2994                   1.0  Roger Ruggles, Sharon Jones, David Brandes, Ar...
# 2995                   1.0                       Stacey Jones, Richard Miller
# 2996             0.9755763                                    Stephen E Jones
# 2997                   1.0                                        Steve Jones
# 2998                   1.0                       Steve Jones, Steve Meyfroidt
# 2999             0.9755763  S M Belmore, J M Yates, D R Bellack, S N Jones...
# 3000                   1.0  Robert A Campbell, Suzanne Jones, Rachelle Cottle
# 3001             0.9755763  S M Bobbio, M D Kellam, B W Dudley, S Goodwin-...
#
#                                                    body editor  \
# 0                                                   NaN    NaN
# 1                                                   NaN    NaN
# 2                                                   NaN    NaN
# 3                                                   NaN    NaN
# 4                                                   NaN    NaN
# 5                                                   NaN    NaN
# 6                                                   NaN    NaN
# 7     1 Introduction This paper adopts the standard ...    NaN
# 8                                                   NaN    NaN
# 9                                                   NaN    NaN
# 10                                                  NaN    NaN
# 11    1 Introduction In sequential decision problems...    NaN
# 12    Introduction An important task for progress in...    NaN
# 13                                                  NaN    NaN
# 14                                                  NaN    NaN
# 15    1 INTRODUCTION Many problems arising in machin...    NaN
# 16    Introduction Over the last twentyyears, probab...    NaN
# 17                                                  NaN    NaN
# 18                                                  NaN    NaN
# 19                                                  NaN    NaN
# 20                                                  NaN    NaN
# 21                                                  NaN    NaN
# 22                                                  NaN    NaN
# 23                                                  NaN    NaN
# 24    1 Introduction An agent acting in the world mu...    NaN
# 25                                                  NaN    NaN
# 26                                                  NaN    NaN
# 27                                                  NaN    NaN
# 28    1 Introduction Reinforcement learning (RL) is ...    NaN
# 29    1 Introduction Object identification---the tas...    NaN
# ...                                                 ...    ...
# 2972                                                NaN    NaN
# 2973                                                NaN    NaN
# 2974                                                NaN    NaN
# 2975                                                NaN    NaN
# 2976                                                NaN    NaN
# 2977                                                NaN    NaN
# 2978                                                NaN    NaN
# 2979                                                NaN    NaN
# 2980                                                NaN    NaN
# 2981                                                NaN    NaN
# 2982                                                NaN    NaN
# 2983                                                NaN    NaN
# 2984                                                NaN    NaN
# 2985                                                NaN    NaN
# 2986  1 Introduction Halstead derived a number of me...    NaN
# 2987                                                NaN    NaN
# 2988                                                NaN    NaN
# 2989                                                NaN    NaN
# 2990                                                NaN    NaN
# 2991                                                NaN    NaN
# 2992                                                NaN    NaN
# 2993                                                NaN    NaN
# 2994                                                NaN    NaN
# 2995                                                NaN    NaN
# 2996                                                NaN    NaN
# 2997                                                NaN    NaN
# 2998                                                NaN    NaN
# 2999                                                NaN    NaN
# 3000                                                NaN    NaN
# 3001                                                NaN    NaN
#
#                                                   email  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                  ang@cs.berkeley.edu
# 12    ftthuang---koller---malik---ogasawara---bobbyr...
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                              russell@cs.berkeley.edu
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                 eyal@cs.berkeley.edu
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                              russell@cs.berkeley.edu
# 29                              tthuang@cs.berkeley.edu
# ...                                                 ...
# 2972                                                NaN
# 2973                                                NaN
# 2974                                                NaN
# 2975                                                NaN
# 2976                                                NaN
# 2977                                                NaN
# 2978                                                NaN
# 2979                                                NaN
# 2980                                                NaN
# 2981                                                NaN
# 2982                                                NaN
# 2983                                                NaN
# 2984                                                NaN
# 2985                                                NaN
# 2986                   spb1@stir.ac.uksbj@cs.stir.ac.uk
# 2987                                                NaN
# 2988                                                NaN
# 2989                                                NaN
# 2990                                                NaN
# 2991                                                NaN
# 2992                                                NaN
# 2993                                                NaN
# 2994                                                NaN
# 2995                                                NaN
# 2996                                                NaN
# 2997                                                NaN
# 2998                                                NaN
# 2999                                                NaN
# 3000                                                NaN
# 3001                                                NaN
#
#                                             institution  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11    Computer Science Division University of Califo...
# 12    Computer Science Division University of Califo...
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                       U.C. Berkeley,
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                          Carnegie Mellon University,
# 22                                                  NaN
# 23                                                  NaN
# 24    Computer Science Division University of Califo...
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28         Computer Science Division, U. of California,
# 29    Computer Science Division University of Califo...
# ...                                                 ...
# 2972                                                NaN
# 2973                                                NaN
# 2974                                                NaN
# 2975                                                NaN
# 2976                                                NaN
# 2977                                                NaN
# 2978                                                NaN
# 2979  Department of Computing Science and Mathematic...
# 2980                                                NaN
# 2981                                                NaN
# 2982  Dept. of Computing Science, University of Stir...
# 2983                                                NaN
# 2984  Programming Research Group, Oxford University ...
# 2985                                                NaN
# 2986  Department of Computing Science and Mathematic...
# 2987                                                NaN
# 2988                                                NaN
# 2989                                                NaN
# 2990  Department of Computer Science, University of ...
# 2991                                                NaN
# 2992                                                NaN
# 2993                 Chalmers University of Technology,
# 2994                                                NaN
# 2995                                                NaN
# 2996                                                NaN
# 2997                                                NaN
# 2998                                                NaN
# 2999                                                NaN
# 3000                                                NaN
# 3001                                                NaN
#
#                                                 journal keyword  \
# 0                                                   NaN     NaN
# 1                                 J Biol Chemyear: 1999     NaN
# 2                                                   NaN     NaN
# 3                         Proc.Natl.Acad.Sci.year: 1993     NaN
# 4                                J.Biol.Chem.year: 1993     NaN
# 5                                                   NaN     NaN
# 6     In Proceedings of the Sixteenth International ...     NaN
# 7                                                   NaN     NaN
# 8     Proc. International Workshop on automatic Spee...     NaN
# 9                           Technical report,year: 1992     NaN
# 10                                                  NaN     NaN
# 11                                                  NaN     NaN
# 12                                                  NaN     NaN
# 13                                      AAAI.year: 1989     NaN
# 14                                       ICMLyear: 2004     NaN
# 15                                                  NaN     NaN
# 16                                                  NaN     NaN
# 17    In Proceedings of the First International Conf...     NaN
# 18                                   In ICML,year: 2001     NaN
# 19                                                  NaN     NaN
# 20                                                  NaN     NaN
# 21    Discrete Event Dynamic Systems: Theory and App...     NaN
# 22    Proceedings of the Fifth International Confere...     NaN
# 23    in 12th International Conference on Pattern Re...     NaN
# 24                                                  NaN     NaN
# 25    Proceedings 12th National Conference on Artifi...     NaN
# 26                                        AI,year: 1996     NaN
# 27                Technical Report KSL-85-12,year: 1985     NaN
# 28                                                  NaN     NaN
# 29                                                  NaN     NaN
# ...                                                 ...     ...
# 2972                                                NaN     NaN
# 2973       Int. J. Human-Computer Studies 45,year: 1996     NaN
# 2974                                                NaN     NaN
# 2975                                Presence,year: 1997     NaN
# 2976                             Trans. AIME,year: 1978     NaN
# 2977                                                NaN     NaN
# 2978  Tech. Monograph PRG-journal: Programming Resea...     NaN
# 2979                 Technical Report TR-116,year: 1994     NaN
# 2980                                                NaN     NaN
# 2981                                     In [year: 1991     NaN
# 2982                 Technical Report TR. 20,year: 1985     NaN
# 2983  In Sixth Annual Glasgow Workshop on Functional...     NaN
# 2984                 Technical Report PRG-34,year: 1983     NaN
# 2985                                                NaN     NaN
# 2986                                                NaN     NaN
# 2987                                                NaN     NaN
# 2988                                                NaN     NaN
# 2989                                                NaN     NaN
# 2990                        Technical report,year: 1992     NaN
# 2991                  In Proceedings of FPCA,year: 1989     NaN
# 2992  In Proceedings Glasgow Workshop on Functional ...     NaN
# 2993                         In Record of theyear: 1995     NaN
# 2994                                                NaN     NaN
# 2995                                                NaN     NaN
# 2996                                                NaN     NaN
# 2997                                                NaN     NaN
# 2998                                                NaN     NaN
# 2999  Journal of Verbal Learning and Verbal Be-havio...     NaN
# 3000                                                NaN     NaN
# 3001  in Proc. 6th IEEE Workshop Micro Electro Mecha...     NaN
#
#                                                   title  year
# 0     A Revision of Investigatons in Number, Data an...   NaN
# 1     Subcellular localization, stoichiometry, and p...   NaN
# 2     GELYMAC: a Macintosh application for calculati...   NaN
# 3     Macrophage nitric oxide synthase gene: two ups...   NaN
# 4     Expression of the nitric oxide synthase gene i...   NaN
# 5          Analogy By Similarity, Analogical reasoning,   NaN
# 6              Theory and application to reward shaping   NaN
# 7               Efficient memory-bounded search methods   NaN
# 8     Expressive probability models for speech recog...   NaN
# 9                                      The RALPH system   NaN
# 10                           Approaches in Engineering,   NaN
# 11    Policy Invariance Under Reward Transformations...   NaN
# 12    Automatic Symbolic Traffic Scene Analysis Usin...   NaN
# 13    Proceedings of the AAAI Spring Symposium on Li...   NaN
# 14       Blog: relational modeling with unknown objects   NaN
# 15                                     Variational MCMC   NaN
# 16    Speech Recognition with Dynamic Bayesian Networks   NaN
# 17     Efficient resource-bounded reasoning in AT-RALPH   NaN
# 18                                     ground knowledge   NaN
# 19       Approximate reasoning using anytime algorithms  1995
# 20    Local Learning in Probabilistic Networks with ...   NaN
# 21                           ear function approximation   NaN
# 22                         Boundaries of operationality   NaN
# 23    Towards robust automatic traffic scene analysi...   NaN
# 24    Temporal Logical Filtering -- Preliminary Results   NaN
# 25     Control strategies for a stochastic planner, in:   NaN
# 26             Optimal composition of real-time systems   NaN
# 27                            The complete guide to MRS   NaN
# 28    Convergence of Reinforcement Learning with Gen...   NaN
# 29          Object Identification in a Bayesian Context   NaN
# ...                                                 ...   ...
# 2972  Human evaluation of Kea, an automatic keyphras...   NaN
# 2973  Which Way Now? Analysing and Easing Inadequaci...   NaN
# 2974                Four Principles of Groupware Design   NaN
# 2975  Virtual Environments for Medical Training and ...   NaN
# 2976  Graphical techniques for determining relative ...   NaN
# 2977  A New Method for Strictness Analysis on Non-Fl...   NaN
# 2978                                 The LispKit Manual   NaN
# 2979  A screen editor written in the miranda functio...   NaN
# 2980  Towards a Purely Functional Debugger for Funct...   NaN
# 2981  Is compile time garbage collection worth the e...   NaN
# 2982   A Formal Specification of an Expert System Shell   NaN
# 2983  The implementer's dilemma: A mathematical mode...   NaN
# 2984  Abstract machine support for purely functional...   NaN
# 2985  Walk Backwards to Happiness - Debugging by Tim...   NaN
# 2986                                      Simon P Booth   NaN
# 2987  Computer-Time Garbage Collection by Sharing An...   NaN
# 2988                         Experiences with Clean I/O   NaN
# 2989                 Linking Databases in Biotechnology   NaN
# 2990                            Translating CBS to LML,   NaN
# 2991  M'etayer. Compile-time garbage collection by s...   NaN
# 2992  Towards a purely functional debugger for funct...   NaN
# 2993              An experiment in compile time garbage   NaN
# 2994  U.S.-Uganda Cooperative Research: Undergraduat...   NaN
# 2995                           STEM Connections HBCU-UP   NaN
# 2996  The Synapse Approach to High System and Databa...   NaN
# 2997  Next Generation Airline Information: Using Con...   NaN
# 2998         Web Services and Java (Position Statement)   NaN
# 2999  Drawing inferences from concrete and abstract ...   NaN
# 3000  A Comparison of Object Oriented Simulation Lan...   NaN
# 3001                         Integrated Force Arrays'',   NaN
#
# [3002 rows x 14 columns]

# %%
# data_frame = pd.read_csv('./authors.csv')
# data_frame.describe()
# Out:
#        author-in-focus-score         year
# count            3002.000000    65.000000
# mean                0.925739  1997.738462
# std                 0.112081     4.338335
# min                 0.507084  1983.000000
# 25%                 0.927770  1995.000000
# 50%                 0.975576  1998.000000
# 75%                 1.000000  2001.000000
# max                 1.000000  2004.000000

# %%
from csv import DictWriter

with open('authors.csv', 'w') as authors_file:
    writer = DictWriter(authors_file, field_names)
    writer.writeheader()
    for row in authors_d:
        writer.writerow(row)
